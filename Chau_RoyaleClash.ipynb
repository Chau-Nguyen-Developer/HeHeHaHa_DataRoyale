# %% [markdown]
# <a href="https://colab.research.google.com/github/Chau-Nguyen-Developer/HeHeHaHa_DataRoyale/blob/main/Chau_RoyaleClash.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown

# %%
import gdown

# %%
file_id = "1sgMvwiuZNyBt86JD3FRVZa5YRi6DpbBj"

# %%
url = f"https://drive.google.com/uc?id={file_id}"

# %% [markdown]
# @everyone DATASET IS HERE WOOT: https://drive.google.com/file/d/1sgMvwiuZNyBt86JD3FRVZa5YRi6DpbBj/view?usp=drive_link 🎊

# %%
# Download the file
gdown.download(url, "dataset.csv", quiet=False)
print("\nFinished downloading dataset.")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1sgMvwiuZNyBt86JD3FRVZa5YRi6DpbBj
# From (redirected): https://drive.google.com/uc?id=1sgMvwiuZNyBt86JD3FRVZa5YRi6DpbBj&confirm=t&uuid=6661fd12-c5d1-4da1-9040-9128260ca511
# To: /content/dataset.csv
# 100%|██████████| 9.87G/9.87G [01:37<00:00, 101MB/s]
# Finished downloading dataset.

# %%
# # Load data using its path
# import pandas as pd

# path = "/content/dataset.csv"
# data = pd.read_csv(path)
# print("\nFinish loading.")

# %%
import pandas as pd
data = pd.read_csv("dataset.csv", nrows=800_000)
print("Done loading.")
# Out:
# Done loading.

# %%
# Check the structure
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800000 entries, 0 to 799999
# Data columns (total 74 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      800000 non-null  int64
#  1   battleTime                      800000 non-null  object
#  2   arena.id                        800000 non-null  float64
#  3   gameMode.id                     800000 non-null  float64
#  4   average.startingTrophies        800000 non-null  float64
#  5   winner.tag                      800000 non-null  object
#  6   winner.startingTrophies         800000 non-null  float64
#  7   winner.trophyChange             800000 non-null  float64
#  8   winner.crowns                   800000 non-null  float64
#  9   winner.kingTowerHitPoints       800000 non-null  float64
#  10  winner.princessTowersHitPoints  784727 non-null  object
# ...

# %% [markdown]
# Columns of winner.princessTowersHitPoints, winner.clan.tag, winner.clan. badgeId, winner.princessTowersHitPoints, winner.clan.tag, winner.clan.badgeId are only columns that has NULL entries.

# %%
# Descriptive Statistics
display(data.describe())
# Out:
#           Unnamed: 0      arena.id   gameMode.id  average.startingTrophies  \
# count  800000.000000  8.000000e+05  8.000000e+05             800000.000000
# mean   399999.500000  5.400005e+07  7.200011e+07               4816.478458
# std    230940.252015  7.331788e+00  9.727730e+01                631.484620
# min         0.000000  5.400000e+07  7.200001e+07                 26.000000
# 25%    199999.750000  5.400005e+07  7.200001e+07               4538.000000
# 50%    399999.500000  5.400005e+07  7.200020e+07               4818.500000
# 75%    599999.250000  5.400005e+07  7.200020e+07               5145.500000
# max    799999.000000  5.400005e+07  7.200020e+07               8184.000000
#
#        winner.startingTrophies  winner.trophyChange  winner.crowns  \
# count            800000.000000        800000.000000  800000.000000
# mean               4816.969311            29.449180       1.769619
# std                 631.688339             1.502183       0.844154
# ...

# %%
# Check some of the entries in the head
data.head()
# Out:
#    Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 0           0  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
# 1           1  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
# 2           2  2020-12-07 07:00:02+00:00  54000049.0   72000201.0
# 3           3  2020-12-07 07:00:03+00:00  54000049.0   72000201.0
# 4           4  2020-12-07 07:00:06+00:00  54000049.0   72000201.0
#
#    average.startingTrophies  winner.tag  winner.startingTrophies  \
# 0                    6590.0  #28RR8PJP0                   6581.0
# 1                    5582.5   #YV9VQUVP                   5592.0
# 2                    5684.0  #LPR2G0Q9L                   5678.0
# 3                    6031.0  #2GL899VCJ                   6035.0
# 4                    5140.0  #9Y2YJPGG2                   5140.0
#
#    winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 0                 31.0            2.0                     4768.0  ...
# ...

# %%
data["winner.elixir.average"]
# Out:
# 0         3.625
# 1         4.125
# 2         3.875
# 3         3.875
# 4         4.125
#           ...
# 799995    3.875
# 799996    4.125
# 799997    3.750
# 799998    4.125
# 799999    2.625
# Name: winner.elixir.average, Length: 800000, dtype: float64

# %%
# See all the name of columns
data.columns
# Out:
# Index(['Unnamed: 0', 'battleTime', 'arena.id', 'gameMode.id',
#        'average.startingTrophies', 'winner.tag', 'winner.startingTrophies',
#        'winner.trophyChange', 'winner.crowns', 'winner.kingTowerHitPoints',
#        'winner.princessTowersHitPoints', 'winner.clan.tag',
#        'winner.clan.badgeId', 'loser.tag', 'loser.startingTrophies',
#        'loser.trophyChange', 'loser.crowns', 'loser.kingTowerHitPoints',
#        'loser.clan.tag', 'loser.clan.badgeId', 'loser.princessTowersHitPoints',
#        'tournamentTag', 'winner.card1.id', 'winner.card1.level',
#        'winner.card2.id', 'winner.card2.level', 'winner.card3.id',
#        'winner.card3.level', 'winner.card4.id', 'winner.card4.level',
#        'winner.card5.id', 'winner.card5.level', 'winner.card6.id',
#        'winner.card6.level', 'winner.card7.id', 'winner.card7.level',
#        'winner.card8.id', 'winner.card8.level', 'winner.cards.list',
#        'winner.totalcard.level', 'winner.troop.count',
# ...

# %%
data.head(1)
# Out:
#    Unnamed: 0                 battleTime    arena.id  gameMode.id  \
# 0           0  2020-12-07 07:00:00+00:00  54000049.0   72000201.0
#
#    average.startingTrophies  winner.tag  winner.startingTrophies  \
# 0                    6590.0  #28RR8PJP0                   6581.0
#
#    winner.trophyChange  winner.crowns  winner.kingTowerHitPoints  ...  \
# 0                 31.0            2.0                     4768.0  ...
#
#                                     loser.cards.list loser.totalcard.level  \
# 0  [26000000, 26000026, 26000030, 26000041, 27000...                   104
#
#    loser.troop.count loser.structure.count  loser.spell.count  \
# 0                  4                     1                  3
#
#    loser.common.count  loser.rare.count  loser.epic.count  \
# 0                   4                 1                 1
#
#   loser.legendary.count  loser.elixir.average
# 0                     2                 3.125
#
# [1 rows x 74 columns]

# %%
data.head(1)["winner.trophyChange"]
# Out:
# 0    31.0
# Name: winner.trophyChange, dtype: float64

# %%
data["winner.cards.list"][0]
# Out:
# '[26000036, 26000043, 26000044, 26000050, 26000054, 26000062, 28000015, 28000016]'

# %%
data.head(1)["winner.cards.list"]
# Out:
# 0    [26000036, 26000043, 26000044, 26000050, 26000...
# Name: winner.cards.list, dtype: object

# %%
data["loser.cards.list"][0]
# Out:
# '[26000000, 26000026, 26000030, 26000041, 27000006, 28000003, 28000004, 28000011]'

# %%
data.head(1)["winner.tag"]
# Out:
# 0    #28RR8PJP0
# Name: winner.tag, dtype: object

# %%
data.head(1)["loser.tag"]
# Out:
# 0    #9UU8P008P
# Name: loser.tag, dtype: object

# %%
data.head(1)["winner.kingTowerHitPoints"]
# Out:
# 0    4768.0
# Name: winner.kingTowerHitPoints, dtype: float64

# %%
data.head(1)["winner.card1.level"]
# Out:
# 0    13
# Name: winner.card1.level, dtype: int64

# %%
data.head(1)["winner.crowns"]
# Out:
# 0    2.0
# Name: winner.crowns, dtype: float64

# %%
data.head(1)["loser.crowns"]
# Out:
# 0    1.0
# Name: loser.crowns, dtype: float64

# %%
data.head(1)["winner.clan.tag"]
# Out:
# 0    #YYL2GJUC
# Name: winner.clan.tag, dtype: object

# %%
data.head(1)["loser.clan.tag"]
# Out:
# 0    #P2PUU9JV
# Name: loser.clan.tag, dtype: object

# %% [markdown]
# ### Clan Performance
# Metrics for each clan:
# - Win rate
# - Average crown difference (winner.crowns - loser.crowns)
# - Average trophy change (trophy gains/losses per match)
# - Net trophies (sum of trophy changes across all members of that clan)
# - Stability (lower standard deviation of trophy change = more consistent)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'battleTime', 'arena.id', 'gameMode.id',
#        'average.startingTrophies', 'winner.tag', 'winner.startingTrophies',
#        'winner.trophyChange', 'winner.crowns', 'winner.kingTowerHitPoints',
#        'winner.princessTowersHitPoints', 'winner.clan.tag',
#        'winner.clan.badgeId', 'loser.tag', 'loser.startingTrophies',
#        'loser.trophyChange', 'loser.crowns', 'loser.kingTowerHitPoints',
#        'loser.clan.tag', 'loser.clan.badgeId', 'loser.princessTowersHitPoints',
#        'tournamentTag', 'winner.card1.id', 'winner.card1.level',
#        'winner.card2.id', 'winner.card2.level', 'winner.card3.id',
#        'winner.card3.level', 'winner.card4.id', 'winner.card4.level',
#        'winner.card5.id', 'winner.card5.level', 'winner.card6.id',
#        'winner.card6.level', 'winner.card7.id', 'winner.card7.level',
#        'winner.card8.id', 'winner.card8.level', 'winner.cards.list',
#        'winner.totalcard.level', 'winner.troop.count',
# ...

# %% [markdown]
# Get rid of column "Tournament Tag"as all entries has NaN value for tournament tag.

# %%
data["tournamentTag"].isna().sum()
# Out:
# np.int64(800000)

# %%
data["gameMode.id"]
# Out:
# 0         72000201.0
# 1         72000201.0
# 2         72000201.0
# 3         72000201.0
# 4         72000201.0
#              ...
# 799995    72000201.0
# 799996    72000201.0
# 799997    72000201.0
# 799998    72000201.0
# 799999    72000201.0
# Name: gameMode.id, Length: 800000, dtype: float64

# %%
data.head(1)["winner.clan.tag"]
# Out:
# 0    #YYL2GJUC
# Name: winner.clan.tag, dtype: object

# %%
data.head(1)["winner.clan.badgeId"]
# Out:
# 0    16000111.0
# Name: winner.clan.badgeId, dtype: float64

# %%
data.head(1)["winner.cards.list"]
# Out:
# 0    [26000036, 26000043, 26000044, 26000050, 26000...
# Name: winner.cards.list, dtype: object

# %%
data.head(1)["winner.totalcard.level"]
# Out:
# 0    104
# Name: winner.totalcard.level, dtype: int64

# %%
# Filter out the columns that I need to compare clan performance
cols = [ 'battleTime',
         'average.startingTrophies',
         'winner.tag',
         'winner.clan.tag',
         'winner.clan.badgeId',
         'winner.startingTrophies',
         'winner.trophyChange',
         'winner.crowns',
         'winner.cards.list',
         'winner.totalcard.level',
         'winner.elixir.average',
         'loser.tag',
         'loser.clan.tag',
         'loser.clan.badgeId',
         'loser.startingTrophies',
         'loser.trophyChange',
         'loser.crowns',
         'loser.cards.list',
         'loser.totalcard.level',
         'loser.elixir.average']

# %%
clan_df = data[cols]

# %%
clan_df.columns
# Out:
# Index(['battleTime', 'average.startingTrophies', 'winner.tag',
#        'winner.clan.tag', 'winner.clan.badgeId', 'winner.startingTrophies',
#        'winner.trophyChange', 'winner.crowns', 'winner.cards.list',
#        'winner.totalcard.level', 'winner.elixir.average', 'loser.tag',
#        'loser.clan.tag', 'loser.clan.badgeId', 'loser.startingTrophies',
#        'loser.trophyChange', 'loser.crowns', 'loser.cards.list',
#        'loser.totalcard.level', 'loser.elixir.average'],
#       dtype='object')

# %% [markdown]
# ### Reshape one row (include winner and loser's info) per match to per player per match
#
# Separate winners and losers and put them into separate rows. One player = One row.

# %%
winners = pd.DataFrame({
    "playerTag": data["winner.tag"],
    "battleTime": data["battleTime"],
    "clanTag": data["winner.clan.tag"],
    "playerStartTrophies": data["winner.startingTrophies"],
    "opponentStartTrophies": data["loser.startingTrophies"],
    "trophyChange": data["winner.trophyChange"],
    "crownsGained": data["winner.crowns"],
    "crownsLost": data["loser.crowns"],
    "result": 1 # Represent winning
})

# %%
losers = pd.DataFrame({
    "playerTag": data["loser.tag"],
    "battleTime": data["battleTime"],
    "clanTag": data["loser.clan.tag"],
    "playerStartTrophies": data["loser.startingTrophies"],
    "opponentStartTrophies": data["winner.startingTrophies"],
    "trophyChange": data["loser.trophyChange"],
    "crownsGained": data["loser.crowns"],
    "crownsLost": data["winner.crowns"],
    "result": 0 # Represent losing
})

# %%
perPlayer = pd.concat([winners, losers], ignore_index=True)
# Generate fresh indices starting from 0 with ignore_index = True
print(type(perPlayer))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
perPlayer.head(5)
# Out:
#     playerTag                 battleTime    clanTag  playerStartTrophies  \
# 0  #28RR8PJP0  2020-12-07 07:00:00+00:00  #YYL2GJUC               6581.0
# 1   #YV9VQUVP  2020-12-07 07:00:00+00:00    #QJ2PJ8               5592.0
# 2  #LPR2G0Q9L  2020-12-07 07:00:02+00:00    #LC8QY8               5678.0
# 3  #2GL899VCJ  2020-12-07 07:00:03+00:00  #2LPULRC2               6035.0
# 4  #9Y2YJPGG2  2020-12-07 07:00:06+00:00   #8C899GY               5140.0
#
#    opponentStartTrophies  trophyChange  crownsGained  crownsLost  result
# 0                 6599.0          31.0           2.0         1.0       1
# 1                 5573.0          28.0           3.0         1.0       1
# 2                 5690.0          31.0           3.0         0.0       1
# 3                 6027.0          29.0           2.0         1.0       1
# 4                 5140.0          30.0           3.0         1.0       1

# %%
# Check to see if any clanTage is Nan
perPlayer["clanTag"].isna().sum()
# Out:
# np.int64(63656)

# %% [markdown]
# There are 63,656 players who do not have clan tag. Will drop them in this analysis.

# %%
perPlayer = perPlayer.dropna(subset=["clanTag"])

# %%
import numpy as np

# %% [markdown]
# "size" --> count how many matches that clan play (aka how many rows per clan)
# "sum" --> count how many wins that clan wins (add up the 1's in the result)
#
# Syntax for .agg()
# newColumnName = (existing_column, aggregation_function)

# %%
# test if any negative values in "trophy change"column
hasNeg = (perPlayer["trophyChange"] < 0).any()
print(hasNeg)
# Out:
# True

# %%
negTrophyChange = perPlayer[perPlayer["trophyChange"] < 0]["trophyChange"]
negTrophyChange
# Out:
# 800000    -31.0
# 800001    -28.0
# 800002    -31.0
# 800003    -29.0
# 800004    -30.0
#            ...
# 1599994   -27.0
# 1599995   -32.0
# 1599996   -26.0
# 1599997   -30.0
# 1599999   -29.0
# Name: trophyChange, Length: 741447, dtype: float64

# %%
# Group each player into their clan tags.
perClanAggregates = perPlayer.groupby("clanTag").agg(
    matches=("result", "size"),
    uniquePlayers=("playerTag", pd.Series.nunique),

    wins=("result", "sum"),
    winRate=("result", "mean"),

    clanCrownGainedTotal = ("crownsGained", "sum"),
    clanCronwGainedAVG = ("crownsGained", "mean"),

    clanTrophyTotal = ("trophyChange", "sum"),
    clanTrophyChange = ("trophyChange", "mean"),

    opponentStartTrophiesAVG = ("opponentStartTrophies", "mean")
).reset_index()

# %%
perPlayer.head(5)
# Out:
#     playerTag                 battleTime    clanTag  playerStartTrophies  \
# 0  #28RR8PJP0  2020-12-07 07:00:00+00:00  #YYL2GJUC               6581.0
# 1   #YV9VQUVP  2020-12-07 07:00:00+00:00    #QJ2PJ8               5592.0
# 2  #LPR2G0Q9L  2020-12-07 07:00:02+00:00    #LC8QY8               5678.0
# 3  #2GL899VCJ  2020-12-07 07:00:03+00:00  #2LPULRC2               6035.0
# 4  #9Y2YJPGG2  2020-12-07 07:00:06+00:00   #8C899GY               5140.0
#
#    opponentStartTrophies  trophyChange  crownsGained  crownsLost  result
# 0                 6599.0          31.0           2.0         1.0       1
# 1                 5573.0          28.0           3.0         1.0       1
# 2                 5690.0          31.0           3.0         0.0       1
# 3                 6027.0          29.0           2.0         1.0       1
# 4                 5140.0          30.0           3.0         1.0       1

# %%
perClanAggregates["clanTag"]
# Out:
# 0         #200000JU
# 1          #20000VC
# 2          #200020C
# 3          #200020P
# 4         #200028G9
#             ...
# 316026    #YYYYUR2J
# 316027    #YYYYUR80
# 316028    #YYYYVPLG
# 316029    #YYYYVQ0R
# 316030    #YYYYVRLV
# Name: clanTag, Length: 316031, dtype: object

# %% [markdown]
# ### Number of unique clans: 316,031

# %%
perClanAggregates
# Out:
#           clanTag  matches  uniquePlayers  wins   winRate  \
# 0       #200000JU        1              1     0  0.000000
# 1        #20000VC        5              4     4  0.800000
# 2        #200020C        2              2     0  0.000000
# 3        #200020P        7              5     4  0.571429
# 4       #200028G9        9              6     4  0.444444
# ...           ...      ...            ...   ...       ...
# 316026  #YYYYUR2J        3              3     1  0.333333
# 316027  #YYYYUR80        2              2     0  0.000000
# 316028  #YYYYVPLG      543             23   543  1.000000
# 316029  #YYYYVQ0R        2              2     0  0.000000
# 316030  #YYYYVRLV        1              1     0  0.000000
#
#         clanCrownGainedTotal  clanCronwGainedAVG  clanTrophyTotal  \
# 0                        0.0            0.000000            -30.0
# 1                        9.0            1.800000             89.0
# 2                        2.0            1.000000            -57.0
# ...

# %% [markdown]
# ### Looking into performance consistency of each clan
#
# Calculate the sample standard deviation of trophy change of the `trophy change` values for each `clan_tag` group

# %% [markdown]
# Low std --> consistent outcomes
# High std --> some win big and some lose big

# %%
perClanAggregates["trophyChangeSTD"] = perClanAggregates["clanTag"].map(
    perPlayer.groupby("clanTag")["trophyChange"].std()
)

# %%
perClanAggregates["trophyChangeSTD"]
# Out:
# 0               NaN
# 1         26.166773
# 2          0.707107
# 3         31.418830
# 4         31.059531
#             ...
# 316026    34.655447
# 316027     0.707107
# 316028     1.133424
# 316029     0.707107
# 316030          NaN
# Name: trophyChangeSTD, Length: 316031, dtype: float64

# %%
perClanAggregates.head(1)
# Out:
#      clanTag  matches  uniquePlayers  wins  winRate  clanCrownGainedTotal  \
# 0  #200000JU        1              1     0      0.0                   0.0
#
#    clanCronwGainedAVG  clanTrophyTotal  clanTrophyChange  \
# 0                 0.0            -30.0             -30.0
#
#    opponentStartTrophiesAVG  trophyChangeSTD
# 0                    4715.0              NaN

# %%
perClanAggregates["trophyChangeSTD"].isna()
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 316026    False
# 316027    False
# 316028    False
# 316029    False
# 316030     True
# Name: trophyChangeSTD, Length: 316031, dtype: bool

# %%
perClanAggregates["trophyChangeSTD"].isna().sum()
# Out:
# np.int64(155616)

# %% [markdown]
# #### As we can see above, there are 155,616 clans that we cannot compute the consistency, as they only do one match.

# %%
perClanAggregates.iloc[316030]
# Out:
# clanTag                     #YYYYVRLV
# matches                             1
# uniquePlayers                       1
# wins                                0
# winRate                           0.0
# clanCrownGainedTotal              1.0
# clanCronwGainedAVG                1.0
# clanTrophyTotal                 -30.0
# clanTrophyChange                -30.0
# opponentStartTrophiesAVG       3029.0
# trophyChangeSTD                   NaN
# Name: 316030, dtype: object

# %% [markdown]
# ### Return all the clands that have only one match

# %%
clanMatchCounts = perPlayer.groupby("clanTag").size()

# %%
type(clanMatchCounts)
# Out:
# pandas.core.series.Series

# %%
clanMatchCounts
# Out:
# clanTag
# #200000JU      1
# #20000VC       5
# #200020C       2
# #200020P       7
# #200028G9      9
#             ...
# #YYYYUR2J      3
# #YYYYUR80      2
# #YYYYVPLG    543
# #YYYYVQ0R      2
# #YYYYVRLV      1
# Length: 316031, dtype: int64

# %%
print(clanMatchCounts[clanMatchCounts == 1])
# Out:
# clanTag
# #200000JU    1
# #20002GUY    1
# #2000L9G     1
# #2000LP9     1
# #2000LYP     1
#             ..
# #YYYYL0Y9    1
# #YYYYQ80L    1
# #YYYYQQPU    1
# #YYYYU9VL    1
# #YYYYVRLV    1
# Length: 155616, dtype: int64

# %% [markdown]
# ### Measure how common single-match clans are
#
# See the percentage of single-match clans

# %%
totalClans = clanMatchCounts.size
print(totalClans)
# Out:
# 316031

# %%
singleMatchClan = clanMatchCounts[clanMatchCounts == 1].sum()

# %%
print((clanMatchCounts == 1).sum())
# A different way to do it
# Out:
# 155616

# %%
print(singleMatchClan)
# Out:
# 155616

# %%
print(f"{singleMatchClan} of {totalClans} clans ({singleMatchClan/totalClans:.2%}) have only one match.")
# Out:
# 155616 of 316031 clans (49.24%) have only one match.

# %% [markdown]
# #### So, 49.24% of total clans have only one match.

# %% [markdown]
# Filter those clans whose single match has negative trophy change (losing).

# %%
type(singleMatchClan)
# Out:
# numpy.int64

# %%
# Out:
# pandas.core.series.Series

# %%
singleMatchClansLIST = clanMatchCounts[clanMatchCounts==1].index

# %%
singleMatchClansLIST
# Out:
# Index(['#200000JU', '#20002GUY', '#2000L9G', '#2000LP9', '#2000LYP', '#2000P0',
#        '#2000PUJ', '#2002LLUP', '#2002LU0J', '#2002PUQ9',
#        ...
#        '#YYYY822', '#YYYY888', '#YYYY8JUP', '#YYYYC8L0', '#YYYYL0PG',
#        '#YYYYL0Y9', '#YYYYQ80L', '#YYYYQQPU', '#YYYYU9VL', '#YYYYVRLV'],
#       dtype='object', name='clanTag', length=155616)

# %%
singleMatchClansLIST.size
# Out:
# 155616

# %%
oneMatchRows = perPlayer[perPlayer["clanTag"].isin(singleMatchClansLIST)]

# %%
type(oneMatchRows)
# Out:
# pandas.core.frame.DataFrame

# %%
oneMatchRows
# Out:
#           playerTag                 battleTime    clanTag  \
# 3955     #9LRU288L8  2020-12-07 09:22:28+00:00  #LV2UY9G8
# 5825     #2GY8CVLGL  2020-12-07 10:53:06+00:00  #LYGQJ0Y0
# 6438      #UYJQYQCP  2020-12-07 11:24:32+00:00  #YJP9LLGC
# 6786     #QQ82R0L20  2020-12-07 11:42:55+00:00  #Q8PLQU2P
# 6962     #2CUPLJQ9Q  2020-12-07 11:49:54+00:00  #L2LQVUUV
# ...             ...                        ...        ...
# 1599979  #P0CL9GRY8  2020-12-18 18:04:00+00:00   #2PJC8LY
# 1599983  #L8GQLJUYC  2020-12-18 18:04:00+00:00  #LG890VYC
# 1599988  #QR820PJCJ  2020-12-18 18:04:00+00:00  #YRP982QY
# 1599993   #YYGQ2LCC  2020-12-18 18:04:01+00:00  #P2GGJJRU
# 1599995  #P88QYGVQL  2020-12-18 18:04:01+00:00  #L8RLCC0V
#
#          playerStartTrophies  opponentStartTrophies  trophyChange  \
# 3955                  4109.0                 4107.0          29.0
# 5825                  4796.0                 4790.0          29.0
# 6438                  5454.0                 5430.0          27.0
# ...

# %%
losingSingleClans=oneMatchRows.loc[oneMatchRows["trophyChange"] < 0, "clanTag"].unique()

# %%
type(losingSingleClans)
# Out:
# numpy.ndarray

# %%
losingSingleClans
# Out:
# array(['#PUG22C2', '#9U88YR9Q', '#2P2U9L9G', ..., '#YRP982QY',
#        '#P2GGJJRU', '#L8RLCC0V'], dtype=object)

# %%
losingSingleClans.size
# Out:
# 152441

# %%
print(f"{losingSingleClans.size} out of {singleMatchClan} ({losingSingleClans.size/singleMatchClansLIST.size:.2%}) single-match clan lose the battle.")
# Out:
# 152441 out of 155616 (97.96%) single-match clan lose the battle.

# %% [markdown]
# ### As we can see above, 97.96% of clans whom only did one match lost the battle.
